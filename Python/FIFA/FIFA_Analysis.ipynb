# %%
import numpy as np
import pandas as pd 

# for visualizations
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/drive/MyDrive/Data Science/data.csv")
print(df.shape)
# Out:
# (18207, 89)

# %%
df.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %% [markdown]
# ## extract countries.

# %%
def country(x):
    return df[df["Nationality"] == x][["Name","Overall","Potential","Position"]]

# %%
# let"s check the Indian Players 
country("India")
# Out:
#                   Name  Overall  Potential Position
# 8605        S. Chhetri       67         67       LS
# 10011       S. Jhingan       65         71      RCB
# 12598    J. Lalpekhlua       63         64       RS
# 12811  G. Singh Sandhu       63         68       GK
# 13508    A. Edathodika       62         62      LCB
# 14054        P. Halder       61         67      RCM
# 14199         P. Kotal       61         66       RB
# 14218         L. Ralte       61         62       LW
# 14705           N. Das       60         65       LB
# 14786         U. Singh       60         67       RM
# 14915       H. Narzary       60         66       LM
# 15356         R. Singh       59         59       ST
# 15643         S. Singh       59         65       CB
# 15652         A. Thapa       59         71      LCM
# 15855       M. Rafique       58         61       CM
# 15864         A. Singh       58         62       GK
# 15884         B. Singh       58         58       ST
# ...

# %% [markdown]
# ## Analyzing Club df( Manchester United)

# %%
def club(x):
    return df[df["Club"] == x][["Name","Jersey Number","Position","Overall","Nationality","Age","Wage","Value","Contract Valid Until"]]

# %%
club("Manchester United")
# Out:
#                   Name  Jersey Number  ...   Value  Contract Valid Until
# 3               De Gea            1.0  ...    €72M                  2020
# 45            P. Pogba            6.0  ...    €64M                  2021
# 47           R. Lukaku            9.0  ...  €62.5M                  2022
# 93          A. Sánchez            7.0  ...  €37.5M                  2022
# 116         A. Martial           11.0  ...  €42.5M                  2019
# 132           N. Matić           31.0  ...    €24M                  2020
# 211          Juan Mata            8.0  ...  €24.5M                  2019
# 250               Fred           17.0  ...  €26.5M                  2023
# 254         J. Lingard            7.0  ...  €26.5M                  2021
# 319        M. Rashford           11.0  ...    €27M                  2020
# 327          E. Bailly            2.0  ...    €21M                  2020
# 374      Ander Herrera           21.0  ...  €17.5M                  2019
# ...

# %%
x = club("Manchester United")
x.shape
# Out:
# (33, 9)

# %% [markdown]
# ### Describing the df

# %%
df.describe()
# Out:
#          Unnamed: 0             ID  ...  GKPositioning    GKReflexes
# count  18207.000000   18207.000000  ...   18159.000000  18159.000000
# mean    9103.000000  214298.338606  ...      16.388898     16.710887
# std     5256.052511   29965.244204  ...      17.034669     17.955119
# min        0.000000      16.000000  ...       1.000000      1.000000
# 25%     4551.500000  200315.500000  ...       8.000000      8.000000
# 50%     9103.000000  221759.000000  ...      11.000000     11.000000
# 75%    13654.500000  236529.500000  ...      14.000000     14.000000
# max    18206.000000  246620.000000  ...      90.000000     94.000000
#
# [8 rows x 44 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %% [markdown]
# Handelling the missing value for the continuous variables for proper df visualization

# %%
df["ShortPassing"].fillna(df["ShortPassing"].mean(), inplace = True)
df["Volleys"].fillna(df["Volleys"].mean(), inplace = True)
df["Dribbling"].fillna(df["Dribbling"].mean(), inplace = True)
df["Curve"].fillna(df["Curve"].mean(), inplace = True)
df["FKAccuracy"].fillna(df["FKAccuracy"], inplace = True)
df["LongPassing"].fillna(df["LongPassing"].mean(), inplace = True)
df["BallControl"].fillna(df["BallControl"].mean(), inplace = True)
df["HeadingAccuracy"].fillna(df["HeadingAccuracy"].mean(), inplace = True)
df["Finishing"].fillna(df["Finishing"].mean(), inplace = True)
df["Crossing"].fillna(df["Crossing"].mean(), inplace = True)
df["Weight"].fillna("200lbs", inplace = True)
df["Contract Valid Until"].fillna(2019, inplace = True)
df["Height"].fillna("5"11", inplace = True)
df["Loaned From"].fillna("None", inplace = True)
df["Joined"].fillna("Jul 1, 2018", inplace = True)
df["Jersey Number"].fillna(8, inplace = True)
df["Body Type"].fillna("Normal", inplace = True)
df["Position"].fillna("ST", inplace = True)
df["Club"].fillna("No Club", inplace = True)
df["Work Rate"].fillna("Medium/ Medium", inplace = True)
df["Skill Moves"].fillna(df["Skill Moves"].median(), inplace = True)
df["Weak Foot"].fillna(3, inplace = True)
df["Preferred Foot"].fillna("Right", inplace = True)
df["International Reputation"].fillna(1, inplace = True)
df["Wage"].fillna("€200K", inplace = True)
df.fillna(0, inplace = True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# ID                0
# Name              0
# Age               0
# Photo             0
#                  ..
# GKHandling        0
# GKKicking         0
# GKPositioning     0
# GKReflexes        0
# Release Clause    0
# Length: 89, dtype: int64

# %%
def defending(df):
    return int(round((df[["Marking","StandingTackle","SlidingTackle"]].mean()).mean()))

# %%
def general(df):
    return int(round((df[["HeadingAccuracy","Dribbling","Curve","BallControl"]].mean()).mean()))

# %%
def mental(df):
    return int(round((df[["Aggression","Interceptions","Positioning","Vision","Composure"]].mean()).mean()))

# %%
def passing(df):
    return int(round((df[["Crossing","ShortPassing","LongPassing"]].mean()).mean()))

# %%
def mobility(df):
    return int(round((df[["Acceleration","SprintSpeed","Agility","Reactions"]].mean()).mean()))

# %%
def power(df):
    return int(round((df[["Balance","Jumping","Stamina","Strength"]].mean()).mean()))

# %%
def rating(df):
    return int(round((df[["Potential","Overall"]].mean()).mean()))

# %%
def shooting(df):
    return int(round((df[["Finishing","Volleys","FKAccuracy","ShotPower","LongShots","Penalties"]].mean()).mean()))

# %% [markdown]
# ## Renaming the columns

# %%
df.rename(columns={"Club Logo":"Club_Logo"}, inplace=True)

# %%
# adding these categories to the df

df["Defending"] = df.apply(defending, axis = 1)
df["General"] = df.apply(general, axis = 1)
df["Mental"] = df.apply(mental, axis = 1)
df["Passing"] = df.apply(passing, axis = 1)
df["Mobility"] = df.apply(mobility, axis = 1)
df["Power"] = df.apply(power, axis = 1)
df["Rating"] = df.apply(rating, axis = 1)
df["Shooting"] = df.apply(shooting, axis = 1)

# %%
players = df[["Name","Defending","General","Mental","Passing","Mobility","Power","Rating","Shooting","Flag","Age","Nationality","Photo","Club_Logo","Club"]]

# %%
players.head()
# Out:
#                 Name  ...                 Club
# 0           L. Messi  ...         FC Barcelona
# 1  Cristiano Ronaldo  ...             Juventus
# 2          Neymar Jr  ...  Paris Saint-Germain
# 3             De Gea  ...    Manchester United
# 4       K. De Bruyne  ...      Manchester City
#
# [5 rows x 15 columns]

# %% [markdown]
# ## <b>Data Visualization</b>

# %% [markdown]
# <b>Comparison of preferred foot over the different players</b>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["Preferred Foot"], palette = "magma")
plt.title("Most Preferred Foot of the Players", fontsize = 20)
plt.show()

# %% [markdown]
# ## <b>Plotting a pie chart to represent share of international reputation.</b>

# %%
labels = ["1", "2", "3", "4", "5"]
sizes = df["International Reputation"].value_counts()
explode = [0.1, 0.1, 0.2, 0.3, 0.4]

plt.figure(figsize=(8,8))
plt.pie(sizes, labels = labels, explode = explode, shadow = True)
plt.title("International Repuatation for the Football Players", fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# ## <b>Different positions acquired by the players</b>

# %%
plt.figure(figsize = (20, 5))
plt.style.use("fivethirtyeight")
sns.countplot("Position", data = df, palette = "bone")
plt.xlabel("Different Positions in Football", fontsize = 16)
plt.ylabel("Count of Players", fontsize = 16)
plt.title("Comparison of Positions and Players", fontsize = 20)
plt.show()

# %% [markdown]
# ## <b>Defining a function for cleaning the Weight data</b>

# %%
def extract_value_from(value):
  out = value.replace("lbs", "")
  return float(out)

# %%
# applying the function to weight column
#data["value"] = data["value"].apply(lambda x: extract_value_from(x))
df["Weight"] = df["Weight"].apply(lambda x : extract_value_from(x))

# %%
df["Weight"].head()
# Out:
# 0    159.0
# 1    183.0
# 2    150.0
# 3    168.0
# 4    154.0
# Name: Weight, dtype: float64

# %% [markdown]
# ## <b>Defining a function for cleaning the wage column</b>

# %%
def extract_value_from(Value):
    out = Value.replace("€", "")
    if "M" in out:
        out = float(out.replace("M", ""))*1000000
    elif "K" in Value:
        out = float(out.replace("K", ""))*1000
    return float(out)

# %%
# Applying the function to the wage column

df["Value"] = df["Value"].apply(lambda x: extract_value_from(x))
df["Wage"] = df["Wage"].apply(lambda x: extract_value_from(x))

# %%
df["Wage"].head()
# Out:
# 0    565000.0
# 1    405000.0
# 2    290000.0
# 3    260000.0
# 4    355000.0
# Name: Wage, dtype: float64

# %% [markdown]
# ## <b>Comparing the players’ Wages</b>

# %%
plt.figure(figsize = (20, 5))
sns.distplot(df["Wage"], color = "blue")
plt.xlabel("Wage Range for Players", fontsize = 16)
plt.ylabel("Count of the Players", fontsize = 16)
plt.title("Distribution of Wages of Players", fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## <b>Skill Moves of Players</b>

# %%
plt.figure(figsize = (20, 5))
sns.countplot(x = "Skill Moves", data = df, palette = "pastel")
plt.title("Count of players on Basis of their skill moves", fontsize = 20)
plt.xlabel("Number of Skill Moves", fontsize = 16)
plt.ylabel("Count", fontsize = 16)
plt.show()

# %% [markdown]
# ## <b>Height of Players</b>

# %%
plt.figure(figsize = (20, 5))
sns.countplot(x = "Height", data = df, palette = "dark")
plt.title("Count of players on Basis of Height", fontsize = 20)
plt.xlabel("Height in Foot per inch", fontsize = 16)
plt.ylabel("Count", fontsize = 16)
plt.show()

# %% [markdown]
# ## <b>To show Different body weight of the players participating in the FIFA 2019</b>

# %%
plt.figure(figsize = (20, 5))
sns.distplot(df["Weight"], color = "r")
plt.title("Different Weights of the Players Participating in FIFA 2019", fontsize = 20)
plt.xlabel("Heights associated with the players", fontsize = 16)
plt.ylabel("count of Players", fontsize = 16)
plt.show()

# %% [markdown]
# ## <b>To show Different Work rate of the players participating in the FIFA 2019</b>

# %%
plt.figure(figsize = (20, 5))
sns.countplot(x = "Work Rate", data = df, palette = "hls")
plt.title("Different work rates of the Players Participating in the FIFA 2019", fontsize = 20)
plt.xlabel("Work rates associated with the players", fontsize = 16)
plt.ylabel("count of Players", fontsize = 16)
plt.show()

# %% [markdown]
# ## <b>To show Different Speciality Score of the players participating in the FIFA 2019</b>

# %%
plt.figure(figsize = (12, 6))
sns.distplot(df.Special, bins = 58, kde  = False, color = "b")
plt.xlabel("Special score range", fontsize = 16)
plt.ylabel("Count of the Players",fontsize = 16)
plt.title("Histogram for the Speciality Scores of the Players", fontsize = 20)
plt.show()

# %% [markdown]
# ## <b>To show Different potential scores of the players participating in the FIFA 2019</b>

# %%
x = df.Potential
plt.figure(figsize=(12,8))
plt.style.use("seaborn-paper")
sns.distplot(x, bins = 58, kde = False, color = "y")
plt.xlabel("Player\"s Potential Scores", fontsize = 16)
plt.ylabel("Number of players", fontsize = 16)
plt.title("Histogram of players Potential Scores", fontsize = 20)
plt.show()

# %% [markdown]
# ## <b>To show Different nations participating in the FIFA 2019</b>

# %%
plt.figure(figsize=(15, 7))
df["Nationality"].value_counts().head(80).plot.bar(color = "orange")
plt.title("Different Nations Participating in FIFA 2019", fontsize = 30, fontweight = 20)
plt.xlabel("Name of The Country")
plt.ylabel("count")
plt.show()

# %% [markdown]
# ## <b>Countries with Most Players</b>
# <p>Picking up the countries with highest number of players to compare their overall scores</p>

# %%
df["Nationality"].value_counts().head()
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: Nationality, dtype: int64

# %% [markdown]
# ## <b>Every Nations’ Player and their Weights</b>

# %%
some_countries = ("England", "Germany", "Spain", "Argentina", "France", "Brazil", "Italy", "Columbia")
df_countries = df.loc[df["Nationality"].isin(some_countries) & df["Weight"]]

# %%
plt.figure(figsize = (15, 7))
sns.violinplot(x = df_countries["Nationality"], y = df_countries["Weight"], palette = "Reds")
plt.xlabel("Countries", fontsize = 9)
plt.ylabel("Weight in lbs", fontsize = 9)
plt.title("Distribution of Weight of players from different countries", fontsize = 20)
plt.show()

# %% [markdown]
# ## <b>Finding the the popular clubs around the globe</b>

# %%
df["Club"].value_counts().head(8)
# Out:
# No Club                241
# TSG 1899 Hoffenheim     33
# Fortuna Düsseldorf      33
# RC Celta                33
# Valencia CF             33
# Eintracht Frankfurt     33
# FC Barcelona            33
# Liverpool               33
# Name: Club, dtype: int64

# %%
some_clubs = ("CD Leganés", "Southampton", "RC Celta", "Empoli", "Fortuna Düsseldorf", "Manchestar City",
             "Tottenham Hotspur", "FC Barcelona", "Valencia CF", "Chelsea", "Real Madrid")
data_clubs = df.loc[df["Club"].isin(some_clubs) & df["Overall"]]

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x = data_clubs["Club"], y = data_clubs["Overall"], palette = "inferno")
plt.xlabel("Some Popular Clubs", fontsize = 9)
plt.ylabel("Overall Score", fontsize = 9)
plt.title("Distribution of Overall Score in Different popular Clubs", fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## <b>Distribution of Wages in some Popular clubs</b>

# %%
some_clubs = ("CD Leganés", "Southampton", "RC Celta", "Empoli", "Fortuna Düsseldorf", "Manchestar City",
             "Tottenham Hotspur", "FC Barcelona", "Valencia CF", "Chelsea", "Real Madrid")

data_club = df.loc[df["Club"].isin(some_clubs) & df["Wage"]]

plt.rcParams["figure.figsize"] = (16, 8)
sns.boxplot(x = "Club", y = "Wage", data = data_club, palette = "Reds")
plt.xlabel("Names of some popular Clubs", fontsize = 10)
plt.ylabel("Distribution", fontsize = 10)
plt.title("Disstribution of Wages in some Popular Clubs", fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## <b>Comparing the performance of left-footed and right-footed footballers</b>

# %%
# ballcontrol vs dribbing
plt.figure()
sns.lmplot(x = "BallControl", y = "Dribbling", data = df, col = "Preferred Foot")
plt.show()
